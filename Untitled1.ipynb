# %%
import pandas as pd

# %%
mtcars = pd.read_csv("mtcarsdata.csv")

# %%
import pandas as pd
mtcars = pd.read_csv("mtcarsdata.csv")

# %%
pd.pivot_table(mtcars,values="mpg", index="am")
# Out:
#           mpg
# am
# 0   17.147368
# 1   24.392308

# %%
pd.pivot_table(mtcars,values="mpg", index="vs")
# Out:
#           mpg
# vs
# 0   16.616667
# 1   24.557143

# %%
pd.pivot_table(mtcars, values="mpg", index="vs", columns="am")
# Out:
# am          0          1
# vs
# 0   15.050000  19.750000
# 1   20.742857  28.371429

# %%
pd.pivot_table(mtcars, values="mpg", index="am", aggfunc="count")
# Out:
#     mpg
# am
# 0    19
# 1    13

# %%
pd.pivot_table(mtcars, values="mpg", index="vs", columns="am", aggfunc="count")
# Out:
# am   0  1
# vs
# 0   12  6
# 1    7  7

# %%
pd.pivot_table(mtcars, values="mpg",index="am", aggfunc="mean")
# Out:
#           mpg
# am
# 0   17.147368
# 1   24.392308
