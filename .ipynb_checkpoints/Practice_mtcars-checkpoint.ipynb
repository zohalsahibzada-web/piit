# %%
print ("Hello Zohal")
# Out:
# Hello Zohal

# %%
import pandas as pd

# %%
import pandas as pd
data = {
    "Name" : [ "Zohal", "Anna", "John"],
    "Age" : [25, 30, 22]

}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Zohal   25
# 1   Anna   30
# 2   John   22

# %%
df. head()
# Out:
#     Name  Age
# 0  Zohal   25
# 1   Anna   30
# 2   John   22

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   25.666667
# std     4.041452
# min    22.000000
# 25%    23.500000
# 50%    25.000000
# 75%    27.500000
# max    30.000000

# %%
df["Age"]
# Out:
# 0    25
# 1    30
# 2    22
# Name: Age, dtype: int64

# %%
df["Age"] .mean()
# Out:
# np.float64(25.666666666666668)

# %%
df[df["Age"] > 25]
# Out:
#    Name  Age
# 1  Anna   30

# %%
df["Age_in_5_years"] = df["Age"] + 5 
df
# Out:
#     Name  Age  Age_in_5_years
# 0  Zohal   25              30
# 1   Anna   30              35
# 2   John   22              27

# %%
df.sort_values("Age")
# Out:
#     Name  Age  Age_in_5_years
# 2   John   22              27
# 0  Zohal   25              30
# 1   Anna   30              35

# %%
df.describe()
# Out:
#              Age  Age_in_5_years
# count   3.000000        3.000000
# mean   25.666667       30.666667
# std     4.041452        4.041452
# min    22.000000       27.000000
# 25%    23.500000       28.500000
# 50%    25.000000       30.000000
# 75%    27.500000       32.500000
# max    30.000000       35.000000

# %%
df[df["Age"] > 25]
# Out:
#    Name  Age  Age_in_5_years
# 1  Anna   30              35

# %%
df.sort_values("Age")
# Out:
#     Name  Age  Age_in_5_years
# 2   John   22              27
# 0  Zohal   25              30
# 1   Anna   30              35

# %%
df["Double Age"] = df["Age"] * 2
df
# Out:
#     Name  Age  Age_in_5_years  Double Age
# 0  Zohal   25              30          50
# 1   Anna   30              35          60
# 2   John   22              27          44

# %%
df.iloc[0]
# Out:
# Name              Zohal
# Age                  25
# Age_in_5_years       30
# Double Age           50
# Name: 0, dtype: object

# %%
df[df["Age"] > 25]
# Out:
#    Name  Age  Age_in_5_years  Double Age
# 1  Anna   30              35          60

# %%
df.sort_values("Age")
# Out:
#     Name  Age  Age_in_5_years  Double Age
# 2   John   22              27          44
# 0  Zohal   25              30          50
# 1   Anna   30              35          60

# %%
df.sort_values("Age", ascending=False)
# Out:
#     Name  Age  Age_in_5_years  Double Age
# 1   Anna   30              35          60
# 0  Zohal   25              30          50
# 2   John   22              27          44

# %%
df[["Name", "Age"]]
# Out:
#     Name  Age
# 0  Zohal   25
# 1   Anna   30
# 2   John   22

# %%
len(df)
# Out:
# 3

# %%
df.sort_values("Age")
# Out:
#     Name  Age  Age_in_5_years  Double Age
# 2   John   22              27          44
# 0  Zohal   25              30          50
# 1   Anna   30              35          60

# %%
df.sort_values("Age",ascending=False)
# Out:
#     Name  Age  Age_in_5_years  Double Age
# 1   Anna   30              35          60
# 0  Zohal   25              30          50
# 2   John   22              27          44

# %%
df[df["Age"] > 24]
# Out:
#     Name  Age  Age_in_5_years  Double Age
# 0  Zohal   25              30          50
# 1   Anna   30              35          60

# %%
df["Age_plus_10"]= df["Age"] + 10
df
# Out:
#     Name  Age  Age_in_5_years  Double Age  Age_plus_10
# 0  Zohal   25              30          50           35
# 1   Anna   30              35          60           40
# 2   John   22              27          44           32

# %%
df.sort_values("Double Age")
# Out:
#     Name  Age  Age_in_5_years  Double Age  Age_plus_10
# 2   John   22              27          44           32
# 0  Zohal   25              30          50           35
# 1   Anna   30              35          60           40

# %%
df[df["Double Age"] > 45]
# Out:
#     Name  Age  Age_in_5_years  Double Age  Age_plus_10
# 0  Zohal   25              30          50           35
# 1   Anna   30              35          60           40

# %%
df["Name"]
# Out:
# 0    Zohal
# 1     Anna
# 2     John
# Name: Name, dtype: str

# %%
df["Age"]
# Out:
# 0    25
# 1    30
# 2    22
# Name: Age, dtype: int64

# %%
df[["Name", "Age"]]
# Out:
#     Name  Age
# 0  Zohal   25
# 1   Anna   30
# 2   John   22

# %%
df["Age"].mean()
# Out:
# np.float64(25.666666666666668)

# %%
df["Age"].max()
# Out:
# np.int64(30)

# %%
df["Age"].min()
# Out:
# np.int64(22)

# %%
df["Age"].sum()
# Out:
# np.int64(77)

# %%
df["Group"] = ["Young","Adult","Young"]
df
# Out:
#     Name  Age  Age_in_5_years  Double Age  Age_plus_10  Group
# 0  Zohal   25              30          50           35  Young
# 1   Anna   30              35          60           40  Adult
# 2   John   22              27          44           32  Young

# %%
df.groupby("Group")["Age"].mean()
# Out:
# Group
# Adult    30.0
# Young    23.5
# Name: Age, dtype: float64

# %%
df.groupby("Group").sum()
# Out:
#             Name  Age  Age_in_5_years  Double Age  Age_plus_10
# Group
# Adult       Anna   30              35          60           40
# Young  ZohalJohn   47              57          94           67

# %% [raw]
# df.describ()
