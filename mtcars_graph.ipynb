# %%
import pandas as pd

mtcars = pd.read_csv("mtcarsdata.csv")
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
mtcars.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 2.9 KB

# %% [raw]
# mtcars.shape

# %%
mtcars.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='str')

# %%
mtcars.isnull().sum()
# Out:
# mpg     0
# cyl     0
# disp    0
# hp      0
# drat    0
# wt      0
# qsec    0
# vs      0
# am      0
# gear    0
# carb    0
# dtype: int64

# %%
mtcars.plot(x='hp', y='mpg', kind='scatter')
# Out:
# <Axes: xlabel='hp', ylabel='mpg'>

# %%
import matplotlib.pyplot as plt

mtcars.plot(x='hp', y='mpg', kind='scatter')
plt.title("Horsepower vs Mileage")
plt.xlabel("Horsepower (hp)")
plt.ylabel("Miles per Gallon(mpg)")
plt.show()

# %%
mtcars['mpg'].mean()
mtcars['hp'].max()
mtcars['wt'].min()
mtcars['wt'].max()
# Out:
# np.float64(5.424)

# %%
mtcars['cyl'].value_counts()
# Out:
# cyl
# 8    14
# 4    11
# 6     7
# Name: count, dtype: int64

# %%
mtcars.groupby('cyl')['mpg'].mean()
# Out:
# cyl
# 4    26.663636
# 6    19.742857
# 8    15.100000
# Name: mpg, dtype: float64

# %%
mtcars.groupby('am')['mpg'].mean()
# Out:
# am
# 0    17.147368
# 1    24.392308
# Name: mpg, dtype: float64

# %%
mtcars.groupby('gear')['mpg'].mean()
# Out:
# gear
# 3    16.106667
# 4    24.533333
# 5    21.380000
# Name: mpg, dtype: float64

# %%
pd.pivot_table(mtcars, values='mpg', index='cyl', columns='am')
# Out:
# am        0          1
# cyl
# 4    22.900  28.075000
# 6    19.125  20.566667
# 8    15.050  15.400000

# %%
mtcars['efficiency'] = mtcars['mpg'].apply(lambda x: 'High' if x > 20 else 'Low')
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb efficiency
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4       High
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4       High
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1       High
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1       High
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2        Low

# %%
mtcars['am'] = mtcars['am'].map({0: 'Automatic' , 1: 'Manual'})
mtcars['vs'] = mtcars['vs'].map({0: 'V-shaped' , 1: 'Straigh'})
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec        vs         am  gear  carb  \
# 0  21.0    6  160.0  110  3.90  2.620  16.46  V-shaped     Manual     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02  V-shaped     Manual     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   Straigh     Manual     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   Straigh  Automatic     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02  V-shaped  Automatic     3     2
#
#   efficiency
# 0       High
# 1       High
# 2       High
# 3       High
# 4        Low

# %%
import matplotlib.pyplot as plt

mtcars.groupby( 'cyl')['mpg'].mean().plot(kind='bar')
plt.title("Average MPG by Cylinders")
plt.xlabel("Cylinders")
plt.ylabel("Average MPG")
plt.show()
