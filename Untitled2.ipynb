# %%
df = pd.DataFrame(data, columns=["Name", "Maths", "English"])

# %%
df
# Out:
#   Name  Maths  English
# 0    A     70       80
# 1    B     60       90
# 2    C     85       88

# %%
pd.melt(df,
        id_vars=["Name"],
        var_name="Subject",
        value_name="Marks")
# Out:
#   Name  Subject  Marks
# 0    A    Maths     70
# 1    B    Maths     60
# 2    C    Maths     85
# 3    A  English     80
# 4    B  English     90
# 5    C  English     88

# %%
df_long = pd.melt(df,
                  id_vars=["Name"],
                  var_name="Subject",
                  value_name="Marks")
df_long.pivot(index="Name", columns="Subject",values="Marks")
# Out:
# Subject  English  Maths
# Name
# A             80     70
# B             90     60
# C             88     85

# %%
df[["Name", "Maths", "English"]]
# Out:
#   Name  Maths  English
# 0    A     70       80
# 1    B     60       90
# 2    C     85       88

# %%
df_long = pd.melt(
    df,
    id_vars=["Name"],
    var_name="Subject",
    value_name="Marks"
)

df_long
# Out:
#   Name  Subject  Marks
# 0    A    Maths     70
# 1    B    Maths     60
# 2    C    Maths     85
# 3    A  English     80
# 4    B  English     90
# 5    C  English     88

# %%
df_long.pivot(index="Name", columns="Subject",values="Marks")
# Out:
# Subject  English  Maths
# Name
# A             80     70
# B             90     60
# C             88     85

# %%
import pandas as pd

data = [
    ["Ali", 75, 82, 90],
    ["Sara",88, 91, 85],
    ["John", 67, 73, 80]

]
df = pd.DataFrame(data, columns=["Name", "Math", "English", "Science"])

# %%
df = pd.DataFrame(data, columns=["Name", "Math", "English", "Science"])
df
# Out:
#    Name  Math  English  Science
# 0   Ali    75       82       90
# 1  Sara    88       91       85
# 2  John    67       73       80

# %%
df_long = pd.melt(
    df,
    id_vars=["Name"],
    var_name="Subject",
    value_name="Marks"
)
df_long
# Out:
#    Name  Subject  Marks
# 0   Ali     Math     75
# 1  Sara     Math     88
# 2  John     Math     67
# 3   Ali  English     82
# 4  Sara  English     91
# 5  John  English     73
# 6   Ali  Science     90
# 7  Sara  Science     85
# 8  John  Science     80

# %%
df_long.pivot(index="Name", columns="Subject", values="Marks")
# Out:
# Subject  English  Math  Science
# Name
# Ali           82    75       90
# John          73    67       80
# Sara          91    88       85
